# %% [markdown]
# 1. заходим в SRA explorer и скачиваем первые 4 файла из PRJEB84057
#
# ![image.png](attachment:fd8f83e6-2b81-4ab2-8e96-d1c7219bb1a4.png)
#
# с помощью написанного bash скрипта скачиваем интересные нам риды
#
# `#!/usr/bin/env bash`
#
# `curl -L ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR142/086/ERR14230586/ERR14230586.fastq.gz -o` `ERR14230586_Illumina_HiSeq_4000_sequencing.fastq.gz`
#
# `curl -L ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR142/095/ERR14230595/ERR14230595.fastq.gz -o` `ERR14230595_Illumina_HiSeq_4000_sequencing.fastq.gz`
#
# `curl -L ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR142/037/ERR14230537/ERR14230537.fastq.gz -o` `ERR14230537_Illumina_HiSeq_4000_sequencing.fastq.gz`
#
# `curl -L ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR142/052/ERR14230552/ERR14230552.fastq.gz -o` `ERR14230552_Illumina_HiSeq_4000_sequencing.fastq.gz`

# %% [markdown]
# теперь пишем скрипт, который запускает fastqc на всех скачанных файлах, затем делает multiqc на полученных данных - получаем HTML отчет. В целом качество
