# %% [markdown]
# # Руками
#
# ![image.png](attachment:b6020797-5092-40f9-92b9-5e3d4899a71c.png)

# %% [markdown]
# # Алгоритм
#
# ## Код, выполняющий выравнивание
#
# ![image.png](attachment:178bf9e1-4a89-4b1b-bca5-b52fe5f0483f.png)

# %% [markdown]
# ## Результаты выравнивания
#
# ![image.png](attachment:b2ad9e03-0d3d-405f-bc1a-61f7a3e34df6.png)
