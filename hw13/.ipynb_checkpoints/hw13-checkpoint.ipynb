# %% [markdown]
# Создаем папку hm_rna_seq и добавляем в нее ссылки
#
# ![image.png](attachment:a00f98b1-0041-4e60-a4c7-9d4b6a8ff757.png)

# %% [markdown]
# после запуска fastqc становится заметно, что тримминг явно не помешает
#
# ![image.png](attachment:8ea00b1f-cff9-4ef6-9636-77ca6cca24ac.png)

# %% [markdown]
# ![image.png](attachment:7975fe54-b39b-4560-b3e7-c23aa450f49e.png)

# %% [markdown]
# Сделали тримминг с помощью fastp и смотрим на результаты QC еще раз
#
# ![image.png](attachment:3c753162-6bc9-4b8b-9e1d-1acf6ac0af80.png)
#
# ![image.png](attachment:86b735c5-81d1-4bc8-802d-e50f52595d8d.png)

# %% [markdown]
# не иедально, но стало получше. первые нуклеотиды все равно не очень хорошие, но будем использовать что есть. для выравнивания рекомендуется использовать trimmed риды, потому что у них выше точность, а значит лучше и достоверность выравнивания

# %%
STAR не запускается, не знаю что делать
