# %% [markdown]
# ## 1. Выбор белков
#
# Я выбрала белок JAK 1 - первая субъединица киназы в JAK/STAT пути врожденного иммунного ответа. В UniProt данный белок был найден для человека, зебрафиш, карпа и мыши
#
# ![image.png](attachment:63d799f3-f44d-446e-93af-32c3e8694d72.png)

# %% [markdown]
# ## 2. Множественное выравнивание
# Произведем множественное выравнивание с помощью Clustal Omega https://www.ebi.ac.uk/jdispatcher/msa/clustalo
#
# Newick файл:
#
# (
# (
# sp|P23458|JAK1_HUMAN:0.0329575
# ,
# sp|P52332|JAK1_MOUSE:0.0329575
# ):0.169296
# ,
# (
# sp|O12990|JAK1_DANRE:0.0676496
# ,
# sp|Q09178|JAK1_CYPCA:0.0676496
# ):0.134604
# )
# ;
#
# Полученное филогенетическое дерево построим в Tree viewer https://etetoolkit.org/treeview/
#
# ![image.png](attachment:eff5eac7-70bf-4927-969f-4f765a154b61.png)

# %% [markdown]
# ## 3. Множественное выравнивние 2
#
# Для сравнения проведем повторное множественное выравнивание с помощью MAFFT https://www.ebi.ac.uk/jdispatcher/msa/muscle
#
# Newick файл:
#
#
# (
# sp|P23458|JAK1_HUMAN:0.02560,
# sp|P52332|JAK1_MOUSE:0.02483,
# (
# sp|O12990|JAK1_DANRE:0.05661,
# sp|Q09178|JAK1_CYPCA:0.07348)
# :0.28248);
#
# Дерево из Tree viewer:
