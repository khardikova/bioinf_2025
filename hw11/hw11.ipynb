# %% [markdown]
# Сборка с семинара выглядит как сборка хорошего качества (по крайней мере для меня). Первая идея как улучшить: посмотреть на качество ридов и сделать тримминг при необходимости
#
# привожу скрины только из одного отчета, но во втором ситуация схожая -- стоит обрезать (для этого я использовала fastp)
#
# ![image.png](attachment:07514d97-fde1-46b1-b007-56442b0d01a2.png)
#
# ![image.png](attachment:1d234934-5357-4b42-b14f-e86b76cf3d6f.png)
#
# ![image.png](attachment:2303c094-b414-483c-92bb-808bcc0593e8.png)

# %% [markdown]
# после тримминга стало намного лучше
#
# ![image.png](attachment:d4a71854-de83-4155-94a4-df511d87d8d7.png)
#
# ![image.png](attachment:ca844f0f-ba0a-42d5-8fae-e0c37207c1fc.png)
#
# ![image.png](attachment:f350912f-65ce-4683-9d47-6ddbc86dbb76.png)

# %% [markdown]
# теперь попробуем сделать сборку, используя k-меры большего диапазона длин -- на семинаре были 39, 49 и 63, я добавлю к этому еще 21, 78, и 99(я не знаю какая должна быть длина, взяла от рандома побольше и поменьше)
#
# теперь запускаем spades и QUAST и получаем отчет -- прилагаю отдельно. там будет видно, что особенно хорошо сработали более короткие 21-меры и более длинные 78-меры

# %% [markdown]
# при запуске blast на один из контигов, собранных из 99-меров, получаем очень высокую точность и 100% query cover
#
# ![image.png](attachment:3175ee7d-5045-4dd7-837e-ea2909665bdf.png)
#
# ![image.png](attachment:5b0a0235-904e-4726-a200-8fcf95ea5374.png)

# %% [markdown]
# посмотрим то же самое для контига из 21-меров -- еще выше точность, и такой же 100% query
#
# ![image.png](attachment:4a63d77c-0b29-4366-a65c-95167663acdb.png)
#
# ![image.png](attachment:8f5106a6-883e-4f86-9178-f28e89ed6789.png)
