# %% [markdown]
# 1. добавим инттересующие нас файлы в папку raw
#
# ![image.png](attachment:a48690e5-6d32-47cb-a86c-366591d277de.png)

# %% [markdown]
# запустим QC и MultiQC и посмотрим на результаты -- видно, что в целом качество ридов вполне хорошее, но GC-content различается
#
# ![image.png](attachment:984158db-8c59-449d-a79f-a150ae4a1378.png)
#
# ![image.png](attachment:a3c3fb9b-0813-42b5-90c0-fbab0050c442.png)

# %% [markdown]
# затем делаем trimming fastp и снова qc/multiqc, разница на лицо -- приведу два "до" и два "после"
#
# ![image.png](attachment:5b6ef6bd-78e6-4811-8f8e-9a5bdff4b2f7.png)
#
# ![image.png](attachment:e4f3e2f6-599e-485a-8377-f249260dde0c.png)
#
# ![image.png](attachment:070a9e39-3935-4362-b591-93965babc1dc.png)
#
# ![image.png](attachment:8d6dc799-a4bd-4e16-b6f6-d5e42aef20e7.png)

# %% [markdown]
# далее делаем Mapping to the reference -- получаем файл aln_pe.sam.gz (посчиталось примерно за 25 часов!!!!!)
#
# теперь сортируем его в sorted.bam, добавляем id образца в риды в bam и потом индексируем -- tagged.bam
#
# посчитаем Sequence coverage = (Number of reads X read length X Paired (2) or single (1) ) / Haploid genome size
#
# ![image.png](attachment:e882c3e0-5fe4-4019-bc60-d59c425acb76.png)

# %% [markdown]
# сделаем визуализацию с помощью IGV, если сайт оживет, но пока недоступно

# %% [markdown]
# gatk считается уже почти 10 часов (и ограничение скоро его остановит, кажется тоже не успеваю доделать...)
#
# ![image.png](attachment:9692a8a7-ce0c-4802-aba5-64e88b593c24.png)
#
# ### но если можно, я дам ему больше времени и пришлю результат
