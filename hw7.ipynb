# %% [markdown]
# # 1.
#
# Сначала в NCBI находим последовательности Spike белка SARS-CoV2 и выбираем несколько
#
# ![image.png](attachment:872d92f3-c3fe-4853-b8aa-d43090ec0d49.png)

# %% [markdown]
# Cоздадим .fasta файл и запишем туда одну из последовательностей, использованных на семинаре, и 4 последовательности из найденных, проведем множественное выравнивание ClustalW
#
# ![image.png](attachment:84ed0b67-8fb6-4f7b-88fc-ff9fa0870487.png)
#
# вот такое дерево получилось -- как выяснилось, таксон с семинара более близок к трем другим, чем последний из найденных мной
#
# ![image.png](attachment:e2495f93-267b-4980-b62b-29db3126fa8c.png)

# %% [markdown]
# # 2.
#
# Нужно выбрать 4-10 ортологов и построить для них дерево -- я использую EGF
#
# ![image.png](attachment:c5eb8bd0-865e-415d-b97b-58c488295a72.png)

# %% [markdown]
# строим точно так же множественное выравнивание и дерево и делаем вывод что эволюцию по EGF лучше не отслеживать
#
# ![image.png](attachment:e133facf-7579-49f7-aae2-dc98e3c15db8.png)
